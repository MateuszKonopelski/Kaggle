# %% [markdown]
# # Fraud detection

# %%
# SET UP ENVIRONMENT 
import pandas as pd

# %%
# IMPORT DATA
dir = 'C:\\Users\\Lenovo\\PycharmProjects\\Kaggle\\Project6_FraudDetection\\data\\'
# train_sample = pd.read_csv(dir + 'train_sample.csv.zip')
# train_sample
chunker = pd.read_csv(dir + 'train.csv.zip', chunksize=100000)
train = pd.DataFrame({'ip': [None], 'app': [None], 'device': [None], 'os': [None], 'channel': [None], 'click_time': [None], 
                      'attributed_time': [None], 'is_attributed': [None]})
for chunk in chunker:
    train = pd.concat([train, chunk])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-65efc1db4d51> in <module>()
#       7                       'attributed_time': [None], 'is_attributed': [None]})
#       8 for chunk in chunker:
# ----> 9     train = pd.concat([train, chunk])
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     210                        keys=keys, levels=levels, names=names,
#     211                        verify_integrity=verify_integrity,
# --> 212                        copy=copy)
#     213     return op.get_result()
#     214
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     273
# ...

# %%
dir = 'C:\\Users\\Lenovo\\PycharmProjects\\Kaggle\\Project6_FraudDetection\\data\\'
train_sample = pd.read_csv(dir + 'train_sample.csv.zip', parse_dates=True)

# %%
# CONVERT DATES TO DATETIME FORMAT
train_sample.click_time = pd.to_datetime(train_sample.click_time)
train_sample.attributed_time = pd.to_datetime(train_sample.attributed_time)
train_sample.dtypes
# Out:
# ip                          int64
# app                         int64
# device                      int64
# os                          int64
# channel                     int64
# click_time         datetime64[ns]
# attributed_time    datetime64[ns]
# is_attributed               int64
# dtype: object

# %% [markdown]
# ## DATES ANALYSIS
# Working with dates. grouping etc

# %%
year = train_sample.click_time.apply(lambda x: x.day)
train_sample.groupby(year)['ip'].count()
# Out:
# click_time
# 6     5011
# 7    32393
# 8    34035
# 9    28561
# Name: ip, dtype: int64

# %%
train_sample.apply(lambda x: x.is_unique)
# Out:
# ip                 False
# app                False
# device             False
# os                 False
# channel            False
# click_time         False
# attributed_time    False
# is_attributed      False
# dtype: bool

# %%
train_sample.isnull().sum()
# Out:
# ip                     0
# app                    0
# device                 0
# os                     0
# channel                0
# click_time             0
# attributed_time    99773
# is_attributed          0
# dtype: int64

# %%
pd.DataFrame({'A': [1, 2, 3], 'B': [5, 6, 7]})['A'].is_unique
# Out:
# True

# %%
train.shape
# Out:
# (10300001, 8)

# %%
train.sort_values('ip').query('is_attributed == 1')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ip</th>
#       <th>app</th>
#       <th>device</th>
#       <th>os</th>
#       <th>channel</th>
#       <th>click_time</th>
#       <th>attributed_time</th>
#       <th>is_attributed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56395</th>
#       <td>2948</td>
#       <td>45</td>
#       <td>1</td>
#       <td>2</td>
#       <td>419</td>
#       <td>2017-11-09 14:30:44</td>
#       <td>2017-11-09 14:30:54</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28269</th>
#       <td>4865</td>
#       <td>19</td>
#       <td>0</td>
#       <td>24</td>
#       <td>213</td>
# ...

# %%
setA = train.groupby('ip')['app'].count()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-7a9e5b5737fb> in <module>()
# ----> 1 setA = train.groupby('ip')['app'].count()
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# ...

# %%
train.columns
# Out:
# Index(['app', 'attributed_time', 'channel', 'click_time', 'device', 'ip',
#        'is_attributed', 'os'],
#       dtype='object')

# %%
import numpy as np
df = pd.DataFrame({'data1': np.random.rand(4), 'data2': np.random.rand(4), 
                   'key1': ['a', 'a', 'b', 'b'],
                   'key2' : ['d', 'f','g', 'g']})
df.groupby('key1')[['data1']].mean()
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#       <th>data2</th>
#       <th>key1</th>
#       <th>key2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.915952</td>
#       <td>0.245459</td>
#       <td>a</td>
#       <td>d</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.761996</td>
#       <td>0.933381</td>
#       <td>a</td>
#       <td>f</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.033672</td>
#       <td>0.040338</td>
#       <td>b</td>
#       <td>g</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.098869</td>
#       <td>0.373645</td>
#       <td>b</td>
# ...

# %%
df.groupby('key1')[['data1']].mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>0.838974</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>0.066270</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby('key1')['data1'].mean()
# Out:
# key1
# a    0.838974
# b    0.066270
# Name: data1, dtype: float64

# %%
type(df.groupby('key1')[['data1']].mean())
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.groupby('key1')['data1'].mean())
# Out:
# pandas.core.series.Series
